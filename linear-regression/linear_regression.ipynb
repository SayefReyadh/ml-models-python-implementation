# %%
# from google.colab import files

# uploaded = files.upload()

# for fn in uploaded.keys():
#   print('User uploaded file "{name}" with length {length} bytes'.format(
#       name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-ac3bebdc-a388-4d9e-918d-3a5680fa16c4" name="files[]" multiple disabled />
#      <output id="result-ac3bebdc-a388-4d9e-918d-3a5680fa16c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car_price.xls to car_price.xls
# Saving econ_customers.csv to econ_customers.csv
# Saving housing_price.csv to housing_price.csv
# Saving xy_data.csv to xy_data.csv
# User uploaded file "car_price.xls" with length 151040 bytes
# User uploaded file "econ_customers.csv" with length 87360 bytes
# User uploaded file "housing_price.csv" with length 726209 bytes
# User uploaded file "xy_data.csv" with length 10384 bytes

# %%
# %matplotlib inline
import numpy as np
from pylab import *

pageSpeeds = np.random.normal(5.0, 1.0, 10)
purchaseAmount =(pageSpeeds + np.random.normal(0, 0.1, 10)) * 10

scatter(pageSpeeds, purchaseAmount)

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)
r_value ** 2
# Out:
# 0.9970303490704279

# %%
import matplotlib.pyplot as plt

def predict(x):
    return slope * x + intercept

fitLine = predict(pageSpeeds)

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='r')
plt.show()
